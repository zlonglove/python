# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r'E:\3cschool\python_shuju_0\dataset\air1908.csv')

# %%
data.head(3)
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
#
#                Operator Flight #          Route              Type  \
# 0  Military - U.S. Army      NaN  Demonstration  Wright Flyer III
# 1  Military - U.S. Navy      NaN    Test flight         Dirigible
# 2               Private        -            NaN  Curtiss seaplane
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# 2          NaN   NaN     1.0         1.0     0.0
#
#                                              Summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  First U.S. dirigible Akron exploded just offsh...
# 2  The first fatal airplane accident in Canada oc...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5268 entries, 0 to 5267
# Data columns (total 13 columns):
# Date            5268 non-null object
# Time            3049 non-null object
# Location        5248 non-null object
# Operator        5250 non-null object
# Flight #        1069 non-null object
# Route           3562 non-null object
# Type            5241 non-null object
# Registration    4933 non-null object
# cn/In           4040 non-null object
# Aboard          5246 non-null float64
# Fatalities      5256 non-null float64
# Ground          5246 non-null float64
# Summary         4878 non-null object
# dtypes: float64(3), object(10)
# memory usage: 535.1+ KB

# %%
#每种机型空难次数

# %%
data.Type.value_counts()
# Out:
# Douglas DC-3                                334
# de Havilland Canada DHC-6 Twin Otter 300     81
# Douglas C-47A                                74
# Douglas C-47                                 62
# Douglas DC-4                                 40
# Yakovlev YAK-40                              37
# Antonov AN-26                                36
# Junkers JU-52/3m                             32
# Douglas C-47B                                29
# De Havilland DH-4                            28
# Douglas DC-6B                                27
# Breguet 14                                   23
# Curtiss C-46A                                21
# Douglas C-47-DL                              20
# Douglas DC-6                                 20
# McDonnell Douglas DC-9-32                    19
# Antonov AN-24                                19
# Antonov AN-12                                19
# Embraer 110P1 Bandeirante                    18
# Curtiss C-46                                 18
# ...

# %%
top10=data.Type.value_counts()[:10]
top10
# Out:
# Douglas DC-3                                334
# de Havilland Canada DHC-6 Twin Otter 300     81
# Douglas C-47A                                74
# Douglas C-47                                 62
# Douglas DC-4                                 40
# Yakovlev YAK-40                              37
# Antonov AN-26                                36
# Junkers JU-52/3m                             32
# Douglas C-47B                                29
# De Havilland DH-4                            28
# Name: Type, dtype: int64

# %%
top10=data.Type.value_counts()[:10].index  #空难次数前10的机型
top10
# Out:
# Index(['Douglas DC-3', 'de Havilland Canada DHC-6 Twin Otter 300',
#        'Douglas C-47A', 'Douglas C-47', 'Douglas DC-4', 'Yakovlev YAK-40',
#        'Antonov AN-26', 'Junkers JU-52/3m', 'Douglas C-47B',
#        'De Havilland DH-4'],
#       dtype='object')

# %%
data_top10=data[data.Type.isin(top10)]  #前10所有空难信息

# %%
data_top10
# Out:
#             Date   Time                               Location  \
# 21    12/16/1918    NaN                  Elizabeth, New Jersey
# 22    05/25/1919    NaN                        Cleveland, Ohio
# 23    07/19/1919    NaN                  Dix Run, Pennsylvania
# 24    10/02/1919    NaN                     Newcastle, England
# 26    10/20/1919    NaN                        English Channel
# 28    03/10/1920    NaN                     New Paris, Indiana
# 29    03/30/1920    NaN                     Newark, New Jersey
# 32    05/12/1920    NaN                        Oskaloosa, Iowa
# 33    06/06/1920    NaN                        Cleveland, Ohio
# 35    08/16/1920    NaN                 College Park, Maryland
# 38    09/27/1920    NaN              Hillersburg, Pennsylvania
# 41    10/15/1920    NaN                      Batavia, Illinois
# 42    11/07/1920    NaN                    Tie Siding, Wyoming
# 45    02/03/1921    NaN                    Mendotta, Minnisota
# ...

# %%
data_top10.count()
# Out:
# Date            753
# Time            291
# Location        750
# Operator        752
# Flight #         91
# Route           458
# Type            753
# Registration    705
# cn/In           610
# Aboard          749
# Fatalities      750
# Ground          750
# Summary         688
# dtype: int64

# %%
data_top10.Location.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 21                      Elizabeth, New Jersey
# 22                            Cleveland, Ohio
# 23                      Dix Run, Pennsylvania
# 24                         Newcastle, England
# 26                            English Channel
# 28                         New Paris, Indiana
# 29                         Newark, New Jersey
# 32                            Oskaloosa, Iowa
# 33                            Cleveland, Ohio
# 35                     College Park, Maryland
# 38                  Hillersburg, Pennsylvania
# 41                          Batavia, Illinois
# 42                        Tie Siding, Wyoming
# 45                        Mendotta, Minnisota
# 48                               Elko, Nevada
# 50                          Mitchel Field, NY
# 51                            Cleveland, Ohio
# 53                  San Francisco, California
# 63                           Nittany Mt, Ohio
# ...

# %%
data['sur']=(data.Aboard-data.Fatalities)/data.Aboard #生存率

# %%
data.head().T
# Out:
#                                                               0  \
# Date                                                 09/17/1908
# Time                                                      17:18
# Location                                    Fort Myer, Virginia
# Operator                                   Military - U.S. Army
# Flight #                                                    NaN
# Route                                             Demonstration
# Type                                           Wright Flyer III
# Registration                                                NaN
# cn/In                                                         1
# Aboard                                                        2
# Fatalities                                                    1
# Ground                                                        0
# Summary       During a demonstration flight, a U.S. Army fly...
# sur                                                         0.5
#
# ...

# %%
data.sort_values(by='sur',ascending=False)
# Out:
#             Date   Time                                      Location  \
# 108   10/21/1926  13:15                               English Channel
# 5074  12/08/2005  19:15                             Chicago, Illinois
# 3428  07/23/1983  19:30                       Gimli, Manitoba, Canada
# 4199  08/18/1993  16:56  Leeward Point Airfield, Guantanamo Bay, Cuba
# 3417  05/05/1983  09:15          En route Miami, FL - Nassau, Bahamas
# 3767  05/24/1988  12:55                        New Orleans, Louisiana
# 2359  12/22/1969  10:30                    Near San Diego, California
# 4171  03/31/1993  12:25                             Anchorage, Alaska
# 5057  08/02/2005  16:04                               Toronto, Canada
# 4068  12/27/1991  08:51                             Stockholm, Sweden
# 4594  10/21/1998  13:51                              Yerevan, Armenia
# 4543  02/03/1998  15:15                  Near Cavalese, Trento, Italy
# ...
